# %%
# %matplotlib inline

# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf

# %%
file = open('../backend/images/food.jpeg', 'rb')

# %%
img = Image.open(file)

# %%
plt.imshow(img)

# %%
img
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
# Out:
# array([[[ 189.,  167.,   58.],
#         [ 189.,  165.,   57.],
#         [ 189.,  165.,   57.],
#         ...,
#         [ 141.,   76.,   48.],
#         [ 144.,   79.,   49.],
#         [ 145.,   80.,   48.]],
#
#        [[ 188.,  166.,   57.],
#         [ 188.,  164.,   56.],
#         [ 189.,  165.,   57.],
#         ...,
#         [ 143.,   78.,   50.],
#         [ 136.,   71.,   41.],
#         [ 131.,   66.,   34.]],
#
#        [[ 187.,  165.,   56.],
#         [ 187.,  165.,   56.],
#         [ 190.,  166.,   58.],
#         ...,
#         [ 139.,   74.,   46.],
#         [ 137.,   72.,   42.],
#         [ 133.,   68.,   36.]],
#
#        ...,
#        [[  85.,  143.,  181.],
#         [  85.,  143.,  183.],
#         [  85.,  143.,  183.],
#         ...,
#         [  30.,   27.,   34.],
#         [  32.,   27.,   34.],
#         [  31.,   26.,   33.]],
#
#        [[  84.,  142.,  180.],
#         [  84.,  142.,  182.],
#         [  84.,  142.,  182.],
#         ...,
# ...

# %%
tf.keras.preprocessing.image.img_to_array(img).shape
# Out:
# (1526, 2295, 3)
